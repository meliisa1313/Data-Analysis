# %% [markdown]
# By: Jan Łucarz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\48660\Desktop\Development Workshop\bitalino\S04_pic2_BITAL.csv"


data = pd.read_csv(path)
data.head()
# Out:
#    lp    EKG  light  blank   EDA   HR  trigger
# 0   0  31292   1164      0  9364  inf        0
# 1   1  31160   1352      0  9386  inf        0
# 2   2  31084   1200      0  9344  inf        0
# 3   3  31056   1125      0  9345  inf        0
# 4   4  31036   1302      0  9364  inf        0

# %%
data.shape
# Out:
# (1774698, 7)

# %%
plt.figure()
plt.plot(data['lp'], data['light'])
plt.ylabel("Value of lightning")
plt.xlabel("Relative timestamp")
plt.title("Lightning condition in time")
plt.show()
